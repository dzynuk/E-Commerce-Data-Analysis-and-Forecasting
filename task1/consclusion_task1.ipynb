# %% [markdown]
# # __Task 1. Прогнозування__

# %% [markdown]
# Машинне навчання краще підходить для прогнозування попиту на короткостроковий період для всіх груп товарів порівняно з класичними методами прогнозування часових рядів. Ось деякі обгрунтування цього вибору:
#
#
# Переваги машинного навчання:
# __Кращі результати__
# __Урахування складних залежностей:__ Машинне навчання може ефективно врахувати складні нелінійні залежності між факторами, такими як тип товару, дати, ціна, пропозиція та інші, що впливають на попит.
# __Обробка великих обсягів даних:__ Моделі машинного навчання можуть ефективно працювати з великими обсягами даних, включаючи дані про товари-новачки, які можуть мати обмежену кількість історичних даних.

# %% [markdown]
# Переваги SARIMAX:
# __Обробка сезонності:__ SARIMAX добре підходить для моделювання та прогнозування часових рядів з сезонними змінами.

# %% [markdown]
# Переваги XGBoost:
# __Швидкістю навчання та прогнозування__
# __Кращі результати__
